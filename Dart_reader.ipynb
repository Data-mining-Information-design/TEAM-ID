# %%
""" !pip install opendartreader
# !pip3 install --upgrade opendartreader
# !pip3 install beautifulsoup4 """

# %%
import OpenDartReader

# %%
api_key = '4b66b1aee7205d6084aae7f8ceaa7c8231c3d38a'
dart = OpenDartReader(api_key)

# %%
#sk하이닉스 개황정보
dart.company('000660')
# Out:
# {'status': '000',
#  'message': '정상',
#  'corp_code': '00164779',
#  'corp_name': '에스케이하이닉스(주)',
#  'corp_name_eng': 'SK hynix Inc.',
#  'stock_name': 'SK하이닉스',
#  'stock_code': '000660',
#  'ceo_nm': '박정호, 이석희 (각자대표)',
#  'corp_cls': 'Y',
#  'jurir_no': '1344110001387',
#  'bizr_no': '1268103725',
#  'adres': '경기도 이천시  부발읍 경충대로 2091',
#  'hm_url': 'www.skhynix.com',
#  'ir_url': '',
#  'phn_no': '031-630-4114',
#  'fax_no': '031-645-8078',
#  'induty_code': '2612',
#  'est_dt': '19491015',
#  'acc_mt': '12'}

# %%
#sk하이닉스 상장이후 모든 공지 목록
dart.list('000660', start='1900')
# Out:
#    corp_code corp_name stock_code corp_cls              report_nm  \
# 0   00164779    SK하이닉스     000660        Y              증권발행실적보고서
# 1   00164779    SK하이닉스     000660        Y                  투자설명서
# 2   00164779    SK하이닉스     000660        Y    [발행조건확정]증권신고서(채무증권)
# 3   00164779    SK하이닉스     000660        Y      기업설명회(IR)개최(안내공시)
# 4   00164779    SK하이닉스     000660        Y    임원ㆍ주요주주특정증권등소유상황보고서
# ..       ...       ...        ...      ...                    ...
# 27  00164779    SK하이닉스     000660        Y          최대주주등에대한부동산임대
# 28  00164779    SK하이닉스     000660        Y  [기재정정]감사보고서 (1999.12)
# 29  00164779    SK하이닉스     000660        Y             최대주주등에대한출자
# 30  00164779    SK하이닉스     000660        Y        반기보고서 (1999.06)
# 31  00164779    SK하이닉스     000660        Y        사업보고서 (1998.12)
#
#           rcept_no  flr_nm  rcept_dt rm
# 0   20210413001836  SK하이닉스  20210413
# 1   20210413000010  SK하이닉스  20210413
# 2   20210412003003  SK하이닉스  20210412
# ...

# %%
#sk하이닉스,배당관련사항,년도별
dart.report('000660', '배당', 2020)
# Out:
#           rcept_no corp_cls corp_code corp_name              se     thstrm  \
# 0   20210330000776        Y  00164779    SK하이닉스       주당액면가액(원)      5,000
# 1   20210330000776        Y  00164779    SK하이닉스  (연결)당기순이익(백만원)  4,755,102
# 2   20210330000776        Y  00164779    SK하이닉스  (별도)당기순이익(백만원)  4,217,841
# 3   20210330000776        Y  00164779    SK하이닉스    (연결)주당순이익(원)      6,952
# 4   20210330000776        Y  00164779    SK하이닉스    현금배당금총액(백만원)    800,282
# 5   20210330000776        Y  00164779    SK하이닉스    주식배당금총액(백만원)          -
# 6   20210330000776        Y  00164779    SK하이닉스   (연결)현금배당성향(%)      16.80
# 7   20210330000776        Y  00164779    SK하이닉스      현금배당수익률(%)       1.00
# 8   20210330000776        Y  00164779    SK하이닉스      현금배당수익률(%)          -
# 9   20210330000776        Y  00164779    SK하이닉스      주식배당수익률(%)          -
# 10  20210330000776        Y  00164779    SK하이닉스      주식배당수익률(%)          -
# ...

# %%
#sk하이닉스 2020 재무제표
dart.finstate('000660', 2020)
# Out:
#           rcept_no reprt_code bsns_year corp_code stock_code fs_div   fs_nm  \
# 0   20210330000776      11011      2020  00164779     000660    CFS  연결재무제표
# 1   20210330000776      11011      2020  00164779     000660    CFS  연결재무제표
# 2   20210330000776      11011      2020  00164779     000660    CFS  연결재무제표
# 3   20210330000776      11011      2020  00164779     000660    CFS  연결재무제표
# 4   20210330000776      11011      2020  00164779     000660    CFS  연결재무제표
# 5   20210330000776      11011      2020  00164779     000660    CFS  연결재무제표
# 6   20210330000776      11011      2020  00164779     000660    CFS  연결재무제표
# 7   20210330000776      11011      2020  00164779     000660    CFS  연결재무제표
# 8   20210330000776      11011      2020  00164779     000660    CFS  연결재무제표
# 9   20210330000776      11011      2020  00164779     000660    CFS  연결재무제표
# 10  20210330000776      11011      2020  00164779     000660    CFS  연결재무제표
# ...
