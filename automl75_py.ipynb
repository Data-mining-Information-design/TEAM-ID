# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#!pip install pycaret
#!pip install autokeras

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import autokeras as ak
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('/content/drive/My Drive/hynix_short.csv', index_col=0, parse_dates=[0], dayfirst=False,infer_datetime_format=True, encoding='cp949')

# %%
from pycaret.classification import *

# %%
data.head()
# Out:
#             삼성등락  등락  등락지표  등락분류  ...    거래량코스닥  변동코스닥    S.P종가  S.P변동률
# date                              ...
# 2010-07-19     0   1     1     1  ...  506010.0  -0.08  1071.25    0.88
# 2010-07-20     1   1     1     1  ...  686750.0   0.25  1083.48    0.80
# 2010-07-21     1   0    -1    -1  ...  721150.0  -0.60  1069.59    1.74
# 2010-07-22     0   0    -1    -1  ...  668020.0  -2.42  1093.67   -1.40
# 2010-07-23     1   1     1     1  ...  532190.0  -0.21  1102.66    1.80
#
# [5 rows x 42 columns]

# %%
data = data.drop(["등락지표", "등락분류", "대비", "등락률"], axis=1)

# %%
clf = setup(data = data, target="삼성등락")
# Out:
#                                Description             Value
# 0                               session_id              7653
# 1                                   Target              삼성등락
# 2                              Target Type            Binary
# 3                            Label Encoded        0: 0, 1: 1
# 4                            Original Data        (2670, 38)
# 5                           Missing Values              True
# 6                         Numeric Features                36
# 7                     Categorical Features                 1
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set        (1868, 23)
# 12                    Transformed Test Set         (802, 23)
# 13                      Shuffle Train-Test              True
# ...

# %%
best3 = compare_models(sort='Accuracy', n_select=3)
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# ridge                    Ridge Classifier    0.7559  0.0000  0.7502  0.7559
# lda          Linear Discriminant Analysis    0.7559  0.8433  0.7502  0.7559
# gbc          Gradient Boosting Classifier    0.7446  0.8353  0.7577  0.7362
# lightgbm  Light Gradient Boosting Machine    0.7350  0.8328  0.7405  0.7302
# rf               Random Forest Classifier    0.7313  0.8221  0.7340  0.7277
# ada                  Ada Boost Classifier    0.7265  0.8214  0.7319  0.7208
# et                 Extra Trees Classifier    0.7008  0.7721  0.6983  0.6987
# dt               Decision Tree Classifier    0.6713  0.6711  0.6593  0.6730
# qda       Quadratic Discriminant Analysis    0.5440  0.5516  0.5061  0.3929
# nb                            Naive Bayes    0.5011  0.4924  0.7405  0.4979
# svm                   SVM - Linear Kernel    0.4941  0.0000  0.2505  0.1417
# ...
